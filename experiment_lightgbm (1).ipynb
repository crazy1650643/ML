# %% [markdown]
# ## Learning Objectives
# At the end of the experiment, you will be able to :
#
# * perform data preprocessing
# * perform feature transformation
# * implement CatBoost, XGBoost and LightGBM model to perform classification using Lending Club dataset

# %% [markdown]
# ## Introduction
#
# **XGBoost** was originally produced by University of Washington researchers and is maintained by open-source contributors. XGBoost is available in Python, R, Java, Ruby, Swift, Julia, C, and C++. Similar to LightGBM, XGBoost uses the gradients of different cuts to select the next cut, but XGBoost also uses the hessian, or second derivative, in its ranking of cuts. Computing this next derivative comes at a slight cost, but it also allows a greater estimation of the cut to use.
#
# **CatBoost** is developed and maintained by the Russian search engine Yandex and is available in Python, R, C++, Java, and also Rust. CatBoost distinguishes itself from LightGBM and XGBoost by focusing on optimizing decision trees for categorical variables, or variables whose different values may have no relation with each other (eg. apples and oranges).
#
# **LightGBM** is a boosting technique and framework developed by Microsoft. The framework implements the LightGBM algorithm and is available in Python, R, and C. LightGBM is unique in that it can construct trees using Gradient-Based One-Sided Sampling, or GOSS for short.
#
# To know more on comparisons between CatBoost, XgBoost and LightGBM, refer below
# - [Article 1](https://towardsdatascience.com/catboost-vs-light-gbm-vs-xgboost-5f93620723db)
# - [Article 2](https://towardsdatascience.com/catboost-vs-lightgbm-vs-xgboost-c80f40662924)

# %% [markdown]
# ## Dataset Description
#
# Lending Club is a lending platform that lends money to people in need at an interest rate based on their credit history and other factors. We will analyze this data and pre-process it based on our need and build a machine learning model that can identify a potential defaulter based on his/her history of transactions with Lending Club.
#
# This dataset contains 42538 rows and 144 columns. **Out of these 144 columns, many columns have majorly null values.**
#
# To know more about the Lending Club dataset features, refer [here](https://www.openintro.org/data/index.php?data=loans_full_schema).

# %% [markdown]
# ###  Import required packages

# %%
# !pip -qq install catboost
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 4.7 MB/s eta 0:00:00

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import DecisionTreeClassifier
from catboost import CatBoostClassifier, Pool, metrics, cv
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Load Dataset

# %%
# Load the raw loan stats dataset
data = pd.read_csv("LoanStats3a.csv")
data.shape
# Out:
# (30834, 144)

# %% [markdown]
# ## Data Preprocessing

# %%
# View the top 5 rows of data
pd.set_option('display.max_columns', None)

data.head(5)
# Out:
#    member_id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0        NaN       5000         5000           4975.0   36 months   10.65%
# 1        NaN       2500         2500           2500.0   60 months   15.27%
# 2        NaN       2400         2400           2400.0   36 months   15.96%
# 3        NaN      10000        10000          10000.0   36 months   13.49%
# 4        NaN       3000         3000           3000.0   60 months   12.69%
#
#    installment grade sub_grade                 emp_title emp_length  \
# 0       162.87     B        B2                       NaN  10+ years
# 1        59.83     C        C4                     Ryder   < 1 year
# 2        84.33     C        C5                       NaN  10+ years
# 3       339.31     C        C1       AIR RESOURCES BOARD  10+ years
# 4        67.79     B        B5  University Medical Group     1 year
#
#   home_ownership  annual_inc verification_status issue_d  loan_status  \
# 0           RENT     24000.0            Verified  Dec-11   Fully Paid
# 1           RENT     30000.0     Source Verified  Dec-11  Charged Off
# 2           RENT     12252.0        Not Verified  Dec-11   Fully Paid
# 3           RENT     49200.0     Source Verified  Dec-11   Fully Paid
# 4           RENT     80000.0     Source Verified  Dec-11   Fully Paid
#
#   pymnt_plan  url                                               desc  \
# 0          n  NaN    Borrower added on 12/22/11 > I need to upgra...
# 1          n  NaN    Borrower added on 12/22/11 > I plan to use t...
# 2          n  NaN                                                NaN
# 3          n  NaN    Borrower added on 12/21/11 > to pay for prop...
# 4          n  NaN    Borrower added on 12/21/11 > I plan on combi...
#
#           purpose                 title zip_code addr_state    dti  \
# 0     credit_card              Computer    860xx         AZ  27.65
# 1             car                  bike    309xx         GA   1.00
# 2  small_business  real estate business    606xx         IL   8.72
# 3           other              personel    917xx         CA  20.00
# 4           other              Personal    972xx         OR  17.94
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0            0           Jan-85               1                     NaN
# 1            0           Apr-99               5                     NaN
# 2            0           Nov-01               2                     NaN
# 3            0           Feb-96               1                    35.0
# 4            0           Jan-96               0                    38.0
#
#    mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0                     NaN         3        0      13648     83.70%          9
# 1                     NaN         3        0       1687      9.40%          4
# 2                     NaN         2        0       2956     98.50%         10
# 3                     NaN        10        0       5598        21%         37
# 4                     NaN        15        0      27783     53.90%         38
#
#   initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 0                   f          0              0   5863.155187
# 1                   f          0              0   1014.530000
# 2                   f          0              0   3005.666844
# 3                   f          0              0  12231.890000
# 4                   f          0              0   4066.908161
#
#    total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0          5833.84          5000.00         863.16                0.00
# 1          1014.53           456.46         435.17                0.00
# 2          3005.67          2400.00         605.67                0.00
# 3         12231.89         10000.00        2214.92               16.97
# 4          4066.91          3000.00        1066.91                0.00
#
#    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0         0.0                     0.00       Jan-15           171.62
# 1       122.9                     1.11       Apr-13           119.66
# 2         0.0                     0.00       Jun-14           649.91
# 3         0.0                     0.00       Jan-15           357.48
# 4         0.0                     0.00       Jan-17            67.30
#
#    next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  \
# 0           NaN             Jul-18                           0
# 1           NaN             Oct-16                           0
# 2           NaN             Jun-17                           0
# 3           NaN             Apr-16                           0
# 4           NaN             Apr-18                           0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN            1       Individual
# 1                          NaN            1       Individual
# 2                          NaN            1       Individual
# 3                          NaN            1       Individual
# 4                          NaN            1       Individual
#
#    annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                        NaN               0
# 1               NaN        NaN                        NaN               0
# 2               NaN        NaN                        NaN               0
# 3               NaN        NaN                        NaN               0
# 4               NaN        NaN                        NaN               0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          NaN                 NaN           NaN      NaN          NaN
# 1          NaN                 NaN           NaN      NaN          NaN
# 2          NaN                 NaN           NaN      NaN          NaN
# 3          NaN                 NaN           NaN      NaN          NaN
# 4          NaN                 NaN           NaN      NaN          NaN
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          NaN         NaN       NaN               NaN     NaN          NaN
# 1          NaN         NaN       NaN               NaN     NaN          NaN
# 2          NaN         NaN       NaN               NaN     NaN          NaN
# 3          NaN         NaN       NaN               NaN     NaN          NaN
# 4          NaN         NaN       NaN               NaN     NaN          NaN
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           NaN                   NaN          NaN             NaN      NaN
# 1           NaN                   NaN          NaN             NaN      NaN
# 2           NaN                   NaN          NaN             NaN      NaN
# 3           NaN                   NaN          NaN             NaN      NaN
# 4           NaN                   NaN          NaN             NaN      NaN
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                       0.0          0.0                 NaN
# 1                       0.0          0.0                 NaN
# 2                       0.0          0.0                 NaN
# 3                       0.0          0.0                 NaN
# 4                       0.0          0.0                 NaN
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                   NaN                    NaN             NaN       NaN
# 1                   NaN                    NaN             NaN       NaN
# 2                   NaN                    NaN             NaN       NaN
# 3                   NaN                    NaN             NaN       NaN
# 4                   NaN                    NaN             NaN       NaN
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                   NaN                       NaN                    NaN
# 1                   NaN                       NaN                    NaN
# 2                   NaN                       NaN                    NaN
# 3                   NaN                       NaN                    NaN
# 4                   NaN                       NaN                    NaN
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                             NaN                    NaN             NaN
# 1                             NaN                    NaN             NaN
# 2                             NaN                    NaN             NaN
# 3                             NaN                    NaN             NaN
# 4                             NaN                    NaN             NaN
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              NaN          NaN        NaN        NaN            NaN
# 1              NaN          NaN        NaN        NaN            NaN
# 2              NaN          NaN        NaN        NaN            NaN
# 3              NaN          NaN        NaN        NaN            NaN
# 4              NaN          NaN        NaN        NaN            NaN
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0            NaN                  NaN       NaN               NaN
# 1            NaN                  NaN       NaN               NaN
# 2            NaN                  NaN       NaN               NaN
# 3            NaN                  NaN       NaN               NaN
# 4            NaN                  NaN       NaN               NaN
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           NaN                 NaN                 NaN             NaN
# 1           NaN                 NaN                 NaN             NaN
# 2           NaN                 NaN                 NaN             NaN
# 3           NaN                 NaN                 NaN             NaN
# 4           NaN                 NaN                 NaN             NaN
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               NaN                   0.0        0.0              NaN
# 1               NaN                   0.0        0.0              NaN
# 2               NaN                   0.0        0.0              NaN
# 3               NaN                   0.0        0.0              NaN
# 4               NaN                   0.0        0.0              NaN
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0                NaN             NaN                         NaN
# 1                NaN             NaN                         NaN
# 2                NaN             NaN                         NaN
# 3                NaN             NaN                         NaN
# 4                NaN             NaN                         NaN
#
#    revol_bal_joint  sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 0              NaN                       NaN                     NaN
# 1              NaN                       NaN                     NaN
# 2              NaN                       NaN                     NaN
# 3              NaN                       NaN                     NaN
# 4              NaN                       NaN                     NaN
#
#    sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 0               NaN               NaN                 NaN
# 1               NaN               NaN                 NaN
# 2               NaN               NaN                 NaN
# 3               NaN               NaN                 NaN
# 4               NaN               NaN                 NaN
#
#    sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                  NaN                    NaN
# 1                  NaN                    NaN
# 2                  NaN                    NaN
# 3                  NaN                    NaN
# 4                  NaN                    NaN
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#    sec_app_mths_since_last_major_derog hardship_flag  hardship_type  \
# 0                                  NaN             N            NaN
# 1                                  NaN             N            NaN
# 2                                  NaN             N            NaN
# 3                                  NaN             N            NaN
# 4                                  NaN             N            NaN
#
#    hardship_reason  hardship_status  deferral_term  hardship_amount  \
# 0              NaN              NaN            NaN              NaN
# 1              NaN              NaN            NaN              NaN
# 2              NaN              NaN            NaN              NaN
# 3              NaN              NaN            NaN              NaN
# 4              NaN              NaN            NaN              NaN
#
#    hardship_start_date  hardship_end_date  payment_plan_start_date  \
# 0                  NaN                NaN                      NaN
# 1                  NaN                NaN                      NaN
# 2                  NaN                NaN                      NaN
# 3                  NaN                NaN                      NaN
# 4                  NaN                NaN                      NaN
#
#    hardship_length  hardship_dpd  hardship_loan_status  \
# 0              NaN           NaN                   NaN
# 1              NaN           NaN                   NaN
# 2              NaN           NaN                   NaN
# 3              NaN           NaN                   NaN
# 4              NaN           NaN                   NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 0                           NaN                Cash                    N
# 1                           NaN                Cash                    N
# 2                           NaN                Cash                    N
# 3                           NaN                Cash                    N
# 4                           NaN                Cash                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN

# %%
# Size of the dataset
data.shape
# Out:
# (30834, 144)

# %%
# Checking info of the raw dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30834 entries, 0 to 30833
# Columns: 144 entries, member_id to settlement_term
# dtypes: float64(103), int64(13), object(28)
# memory usage: 33.9+ MB

# %% [markdown]
# ### Check for missing values in the dataset

# %%
# Check missing values
data.isnull().sum()
# Out:
# member_id                30834
# loan_amnt                    0
# funded_amnt                  0
# funded_amnt_inv              0
# term                         0
#                          ...
# settlement_status        30705
# settlement_date          30705
# settlement_amount        30705
# settlement_percentage    30705
# settlement_term          30705
# Length: 144, dtype: int64

# %%
# Total percentage of null values in the data
pct = (data.isnull().sum().sum())/(data.shape[0]*data.shape[1])
print("Overall missing values in the data ≈ {:.2f} %".format(pct*100))
# Out:
# Overall missing values in the data ≈ 62.55 %

# %% [markdown]
# From above we can see that, about 63% of the values in the overall data are null values.
#
# Let's visualize the null values using the heatmap.

# %%
# Checking for null values using a heatmap as a visualizing tool
plt.figure(figsize=(16,14))
sns.heatmap(data.isnull())
plt.title('Null values heat plot', fontdict={'fontsize': 20})
plt.legend(data.isnull())
plt.show()

# %% [markdown]
# As we can see from the above heatmap, there are lot of null values in the dataset. We have to carefully deal with these null values.

# %% [markdown]
# ### Handling missing values in the data
#
# - Select columns having null values less than 40%

# %%
# Creating a dataframe to display percentage of null values in different number of columns
missing_percentage = (data.isnull().sum() / len(data)) * 100

# Define the ranges
ranges = {
    '10% or less': (missing_percentage <= 10),
    '10% to 20%': (missing_percentage > 10) & (missing_percentage <= 20),
    '20% to 30%': (missing_percentage > 20) & (missing_percentage <= 30),
    '30% to 40%': (missing_percentage > 30) & (missing_percentage <= 40),
    '40% to 50%': (missing_percentage > 40) & (missing_percentage <= 50),
    '50% to 60%': (missing_percentage > 50) & (missing_percentage <= 60),
    '60% to 70%': (missing_percentage > 60) & (missing_percentage <= 70),
    '70% to 80%': (missing_percentage > 70) & (missing_percentage <= 80),
    '80% to 90%': (missing_percentage > 80) & (missing_percentage <= 90),
    'More than 90%': (missing_percentage > 90),
}

# Count the number of columns in each range
column_counts = {key: missing_percentage[condition].count() for key, condition in ranges.items()}

# Create the DataFrame
temp_df = pd.DataFrame(list(column_counts.items()), columns=['Percentage of null values', 'No. of columns'])
temp_df
# Out:
#   Percentage of null values  No. of columns
# 0               10% or less              53
# 1                10% to 20%               0
# 2                20% to 30%               0
# 3                30% to 40%               1
# 4                40% to 50%               0
# 5                50% to 60%               0
# 6                60% to 70%               1
# 7                70% to 80%               0
# 8                80% to 90%               0
# 9             More than 90%              89

# %% [markdown]
# From the above results, we can see that there are only 53 columns out of 144 columns that have null values less than 40%.

# %%
# Considering only those columns which have null values less than 40% in that particular column
df1 = data[data.columns[((data.isnull().sum())/len(data)) < 0.4]]
df1.shape
# Out:
# (30834, 54)

# %% [markdown]
# By considering columns with less number of null values, we were able to decrease total number of columns from 144 to 53.
#
# Note that we will deal with null values present in these selected 53 columns later below.

# %% [markdown]
# ### Removing columns having single distinct value

# %%
# Checking columns that have only single values in them i.e, constant columns
const_cols = []
for i in df1.columns:
    if df1[i].nunique() == 1:
        const_cols.append(i)

print(const_cols)
# Out:
# ['pymnt_plan', 'initial_list_status', 'out_prncp', 'out_prncp_inv', 'collections_12_mths_ex_med', 'policy_code', 'application_type', 'acc_now_delinq', 'chargeoff_within_12_mths', 'delinq_amnt', 'tax_liens', 'hardship_flag', 'disbursement_method']

# %%
# After observing the above output, we are dropping columns which have single values in them
print("Shape before:", df1.shape)
df1.drop(const_cols, axis=1, inplace = True)
print("Shape after:", df1.shape)
# Out:
# Shape before: (30834, 54)
# Shape after: (30834, 41)

# %% [markdown]
# ### Extract features from datetime columns

# %%
# Columns other than numerical value
colms = df1.columns[df1.dtypes == 'object']
colms
# Out:
# Index(['term', 'int_rate', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'verification_status', 'issue_d', 'loan_status',
#        'desc', 'purpose', 'title', 'zip_code', 'addr_state',
#        'earliest_cr_line', 'revol_util', 'last_pymnt_d', 'last_credit_pull_d',
#        'debt_settlement_flag'],
#       dtype='object')

# %%
# Check which columns needs to be converted to datetime
df1[colms].head(2)
# Out:
#          term int_rate grade sub_grade emp_title emp_length home_ownership  \
# 0   36 months   10.65%     B        B2       NaN  10+ years           RENT
# 1   60 months   15.27%     C        C4     Ryder   < 1 year           RENT
#
#   verification_status issue_d  loan_status  \
# 0            Verified  Dec-11   Fully Paid
# 1     Source Verified  Dec-11  Charged Off
#
#                                                 desc      purpose     title  \
# 0    Borrower added on 12/22/11 > I need to upgra...  credit_card  Computer
# 1    Borrower added on 12/22/11 > I plan to use t...          car      bike
#
#   zip_code addr_state earliest_cr_line revol_util last_pymnt_d  \
# 0    860xx         AZ           Jan-85     83.70%       Jan-15
# 1    309xx         GA           Apr-99      9.40%       Apr-13
#
#   last_credit_pull_d debt_settlement_flag
# 0             Jul-18                    N
# 1             Oct-16                    N

# %%
# Converting objects to datetime columns
dt_cols = ['issue_d', 'earliest_cr_line', 'last_pymnt_d', 'last_credit_pull_d']
for i in dt_cols:
    df1[i] = pd.to_datetime(df1[i].astype('str'), format='%b-%y', yearfirst=False)

# %%
# Checking the new datetime columns
df1[['issue_d','earliest_cr_line','last_pymnt_d','last_credit_pull_d']].head()
# Out:
#      issue_d earliest_cr_line last_pymnt_d last_credit_pull_d
# 0 2011-12-01       1985-01-01   2015-01-01         2018-07-01
# 1 2011-12-01       1999-04-01   2013-04-01         2016-10-01
# 2 2011-12-01       2001-11-01   2014-06-01         2017-06-01
# 3 2011-12-01       1996-02-01   2015-01-01         2016-04-01
# 4 2011-12-01       1996-01-01   2017-01-01         2018-04-01

# %%
# Considering only year of joining for 'earliest_cr_line' column
df1['earliest_cr_line'] = pd.DatetimeIndex(df1['earliest_cr_line']).year

# %%
# Adding new features by getting month and year from [issue_d, last_pymnt_d, and last_credit_pull_d] columns
df1['issue_d_year'] = pd.DatetimeIndex(df1['issue_d']).year
df1['issue_d_month'] = pd.DatetimeIndex(df1['issue_d']).month
df1['last_pymnt_d_year'] = pd.DatetimeIndex(df1['last_pymnt_d']).year
df1['last_pymnt_d_month'] = pd.DatetimeIndex(df1['last_pymnt_d']).month
df1['last_credit_pull_d_year'] = pd.DatetimeIndex(df1['last_credit_pull_d']).year
df1['last_credit_pull_d_month'] = pd.DatetimeIndex(df1['last_credit_pull_d']).month

# %%
# Feature extraction
df1.earliest_cr_line = 2019 - (df1.earliest_cr_line)
df1.issue_d_year = 2019 - (df1.issue_d_year)
df1.last_pymnt_d_year = 2019 - (df1.last_pymnt_d_year)
df1.last_credit_pull_d_year = 2019 - (df1.last_credit_pull_d_year)

# %%
# Dropping the original features to avoid data redundancy
df1.drop(['issue_d','last_pymnt_d','last_credit_pull_d'], axis=1, inplace=True)
df1.shape
# Out:
# (30834, 44)

# %% [markdown]
# ### Check for missing values in reduced dataset

# %%
# Checking for null values in the updated dataframe
plt.figure(figsize=(16,10))
sns.heatmap(df1.isnull())
plt.show()

# %% [markdown]
# ### Handling Null values in reduced dataset

# %%
# Checking for Percentage of null values
a = (df1.isnull().sum() / df1.shape[0]) * 100
b = a[a > 0.00]
b = pd.DataFrame(b, columns = ['Percentage of null values'])
b.sort_values(by= ['Percentage of null values'], ascending=False)
# Out:
#                           Percentage of null values
# desc                                      39.865084
# emp_title                                  6.210677
# emp_length                                 3.314523
# last_pymnt_d_year                          0.162159
# last_pymnt_d_month                         0.162159
# revol_util                                 0.077836
# title                                      0.029189
# pub_rec_bankruptcies                       0.003243
# debt_settlement_flag                       0.003243
# last_credit_pull_d_year                    0.003243
# last_credit_pull_d_month                   0.003243

# %%
# Dropping the 29 rows which have null values in few columns
df1 = df1[df1['delinq_2yrs'].notnull()]
df1.shape
# Out:
# (30834, 44)

# %%
# Checking again for Percentage of null values
a = (df1.isnull().sum() / df1.shape[0]) * 100
b = a[a > 0.00]
b = pd.DataFrame(b, columns = ['Percentage of null values'])
b.sort_values(by= ['Percentage of null values'], ascending=False)
# Out:
#                           Percentage of null values
# desc                                      39.865084
# emp_title                                  6.210677
# emp_length                                 3.314523
# last_pymnt_d_year                          0.162159
# last_pymnt_d_month                         0.162159
# revol_util                                 0.077836
# title                                      0.029189
# pub_rec_bankruptcies                       0.003243
# debt_settlement_flag                       0.003243
# last_credit_pull_d_year                    0.003243
# last_credit_pull_d_month                   0.003243

# %% [markdown]
# Now, imputing the missing values with the median value for columns **'last_pymnt_d_year', 'last_pymnt_d_month', 'last_credit_pull_d_year', 'last_credit_pull_d_month', 'tax_liens'** as null values in these columns are less than 0.5% of the size.

# %%
# Clean the column names by stripping extra spaces
df1.columns = df1.columns.str.strip()

# Check and fill null values for 'tax_liens' if it exists
if 'tax_liens' in df1.columns:
    df1['tax_liens'].fillna(df1['tax_liens'].median(), inplace=True)
else:
    print("Column 'tax_liens' does not exist.")

# Fill null values for other columns
df1['last_pymnt_d_year'].fillna(df1['last_pymnt_d_year'].median(), inplace=True)
df1['last_pymnt_d_month'].fillna(df1['last_pymnt_d_month'].median(), inplace=True)
df1['last_credit_pull_d_year'].fillna(df1['last_credit_pull_d_year'].median(), inplace=True)
df1['last_credit_pull_d_month'].fillna(df1['last_credit_pull_d_month'].median(), inplace=True)

# Since 'tax_liens' doesn't exist, you don't need this line:
# df1['tax_liens'].fillna(df1['tax_liens'].median(), inplace=True)
# Out:
# Column 'tax_liens' does not exist.

# %% [markdown]
# For **'revol_util'** column, filling null values with median(string) which is close to 50:

# %%
# For 'revol_util' column, fill null values with 50%
df1.revol_util.fillna('50%', inplace=True)

# Extracting numerical value from string
df1.revol_util = df1.revol_util.apply(lambda x: x[:-1])

# Converting string to float
df1.revol_util = df1.revol_util.astype('float')

# %%
# Unique values in 'pub_rec_bankruptcies' column
df1.pub_rec_bankruptcies.value_counts()
# Out:
# pub_rec_bankruptcies
# 0.0    29467
# 1.0     1360
# 2.0        6
# Name: count, dtype: int64

# %% [markdown]
# From the above we can see that the **'pub_rec_bankruptcies'** column is highly imbalanced. So, it is better to fill it with median(0) value as even after building model the model will be skewed very much towards 0.

# %%
# Fill 'pub_rec_bankruptcies' column
df1['pub_rec_bankruptcies'].fillna(df1['pub_rec_bankruptcies'].median(), inplace=True)

# %%
# Unique values in 'emp_length' column
df1['emp_length'].value_counts()
# Out:
# emp_length
# 10+ years    7363
# 3 years      3191
# 2 years      3180
# < 1 year     3091
# 4 years      2722
# 5 years      2683
# 1 year       2175
# 6 years      1842
# 7 years      1442
# 8 years      1163
# 9 years       960
# Name: count, dtype: int64

# %%
# Seperating null values by assigning a random string
df1['emp_length'].fillna('5000',inplace=True)

# Filling '< 1 year' as '0 years' of experience and '10+ years' as '10 years'
df1.emp_length.replace({'10+ years':'10 years', '< 1 year':'0 years'}, inplace=True)

# Then extract numerical value from the string
df1.emp_length = df1.emp_length.apply(lambda x: x[:2])

# Converting it's dattype to float
df1.emp_length = df1.emp_length.astype('float')

# %%
# Checking again for Percentage of null values
a = (df1.isnull().sum() / df1.shape[0]) * 100
b = a[a > 0.00]
b = pd.DataFrame(b, columns = ['Percentage of null values'])
b.sort_values(by= ['Percentage of null values'], ascending=False)
# Out:
#                       Percentage of null values
# desc                                  39.865084
# emp_title                              6.210677
# title                                  0.029189
# debt_settlement_flag                   0.003243

# %%
# Removing redundant features and features which have percentage null values > 5%
df1.drop(['desc', 'emp_title', 'title'], axis = 1, inplace = True)
df1.isnull().sum()
# Out:
# loan_amnt                   0
# funded_amnt                 0
# funded_amnt_inv             0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# emp_length                  0
# home_ownership              0
# annual_inc                  0
# verification_status         0
# loan_status                 0
# purpose                     0
# zip_code                    0
# addr_state                  0
# dti                         0
# delinq_2yrs                 0
# earliest_cr_line            0
# inq_last_6mths              0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                  0
# total_acc                   0
# total_pymnt                 0
# total_pymnt_inv             0
# total_rec_prncp             0
# total_rec_int               0
# total_rec_late_fee          0
# recoveries                  0
# collection_recovery_fee     0
# last_pymnt_amnt             0
# pub_rec_bankruptcies        0
# debt_settlement_flag        1
# issue_d_year                0
# issue_d_month               0
# last_pymnt_d_year           0
# last_pymnt_d_month          0
# last_credit_pull_d_year     0
# last_credit_pull_d_month    0
# dtype: int64

# %% [markdown]
# ### Converting categorical columns to numerical columns

# %%
df1.head(2)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0       5000         5000           4975.0   36 months   10.65%       162.87
# 1       2500         2500           2500.0   60 months   15.27%        59.83
#
#   grade sub_grade  emp_length home_ownership  annual_inc verification_status  \
# 0     B        B2        10.0           RENT     24000.0            Verified
# 1     C        C4         0.0           RENT     30000.0     Source Verified
#
#    loan_status      purpose zip_code addr_state    dti  delinq_2yrs  \
# 0   Fully Paid  credit_card    860xx         AZ  27.65            0
# 1  Charged Off          car    309xx         GA   1.00            0
#
#    earliest_cr_line  inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  \
# 0                34               1         3        0      13648        83.7
# 1                20               5         3        0       1687         9.4
#
#    total_acc  total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# 0          9  5863.155187          5833.84          5000.00         863.16
# 1          4  1014.530000          1014.53           456.46         435.17
#
#    total_rec_late_fee  recoveries  collection_recovery_fee  last_pymnt_amnt  \
# 0                 0.0         0.0                     0.00           171.62
# 1                 0.0       122.9                     1.11           119.66
#
#    pub_rec_bankruptcies debt_settlement_flag  issue_d_year  issue_d_month  \
# 0                   0.0                    N             8             12
# 1                   0.0                    N             8             12
#
#    last_pymnt_d_year  last_pymnt_d_month  last_credit_pull_d_year  \
# 0                4.0                 1.0                      1.0
# 1                6.0                 4.0                      3.0
#
#    last_credit_pull_d_month
# 0                       7.0
# 1                      10.0

# %%
# Unique values in 'term' column
df1['term'].unique()
# Out:
# array([' 36 months', ' 60 months'], dtype=object)

# %%
# Unique values in 'int_rate' column
df1['int_rate'].unique()[:5]
# Out:
# array(['10.65%', '15.27%', '15.96%', '13.49%', '12.69%'], dtype=object)

# %%
# Converting 'term' and 'int_rate' to numerical columns
df1.term = df1.term.apply(lambda x: x[1:3])
df1.term = df1.term.astype('float')
df1.int_rate = df1.int_rate.apply(lambda x: x[:2])
df1.int_rate = df1.int_rate.astype('float')
df1.head(2)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0       5000         5000           4975.0  36.0      10.0       162.87     B
# 1       2500         2500           2500.0  60.0      15.0        59.83     C
#
#   sub_grade  emp_length home_ownership  annual_inc verification_status  \
# 0        B2        10.0           RENT     24000.0            Verified
# 1        C4         0.0           RENT     30000.0     Source Verified
#
#    loan_status      purpose zip_code addr_state    dti  delinq_2yrs  \
# 0   Fully Paid  credit_card    860xx         AZ  27.65            0
# 1  Charged Off          car    309xx         GA   1.00            0
#
#    earliest_cr_line  inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  \
# 0                34               1         3        0      13648        83.7
# 1                20               5         3        0       1687         9.4
#
#    total_acc  total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# 0          9  5863.155187          5833.84          5000.00         863.16
# 1          4  1014.530000          1014.53           456.46         435.17
#
#    total_rec_late_fee  recoveries  collection_recovery_fee  last_pymnt_amnt  \
# 0                 0.0         0.0                     0.00           171.62
# 1                 0.0       122.9                     1.11           119.66
#
#    pub_rec_bankruptcies debt_settlement_flag  issue_d_year  issue_d_month  \
# 0                   0.0                    N             8             12
# 1                   0.0                    N             8             12
#
#    last_pymnt_d_year  last_pymnt_d_month  last_credit_pull_d_year  \
# 0                4.0                 1.0                      1.0
# 1                6.0                 4.0                      3.0
#
#    last_credit_pull_d_month
# 0                       7.0
# 1                      10.0

# %% [markdown]
# Among the address related features, considering **'addr_state'** column and excluding **'zip_code'** column.

# %%
df2 = df1.drop('zip_code', axis = 1)

# %%
# One hot encoding on categorical columns
df2 = pd.get_dummies(df2, columns = ['home_ownership', 'verification_status', 'purpose', 'addr_state', 'debt_settlement_flag'], drop_first = True)
df2.head(2)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0       5000         5000           4975.0  36.0      10.0       162.87     B
# 1       2500         2500           2500.0  60.0      15.0        59.83     C
#
#   sub_grade  emp_length  annual_inc  loan_status    dti  delinq_2yrs  \
# 0        B2        10.0     24000.0   Fully Paid  27.65            0
# 1        C4         0.0     30000.0  Charged Off   1.00            0
#
#    earliest_cr_line  inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  \
# 0                34               1         3        0      13648        83.7
# 1                20               5         3        0       1687         9.4
#
#    total_acc  total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# 0          9  5863.155187          5833.84          5000.00         863.16
# 1          4  1014.530000          1014.53           456.46         435.17
#
#    total_rec_late_fee  recoveries  collection_recovery_fee  last_pymnt_amnt  \
# 0                 0.0         0.0                     0.00           171.62
# 1                 0.0       122.9                     1.11           119.66
#
#    pub_rec_bankruptcies  issue_d_year  issue_d_month  last_pymnt_d_year  \
# 0                   0.0             8             12                4.0
# 1                   0.0             8             12                6.0
#
#    last_pymnt_d_month  last_credit_pull_d_year  last_credit_pull_d_month  \
# 0                 1.0                      1.0                       7.0
# 1                 4.0                      3.0                      10.0
#
#    home_ownership_OTHER  home_ownership_OWN  home_ownership_RENT  \
# 0                 False               False                 True
# 1                 False               False                 True
#
#    verification_status_Source Verified  verification_status_Verified  \
# 0                                False                          True
# 1                                 True                         False
#
#    purpose_credit_card  purpose_debt_consolidation  purpose_educational  \
# 0                 True                       False                False
# 1                False                       False                False
#
#    purpose_home_improvement  purpose_house  purpose_major_purchase  \
# 0                     False          False                   False
# 1                     False          False                   False
#
#    purpose_medical  purpose_moving  purpose_other  purpose_renewable_energy  \
# 0            False           False          False                     False
# 1            False           False          False                     False
#
#    purpose_small_business  purpose_vacation  purpose_wedding  addr_state_AL  \
# 0                   False             False            False          False
# 1                   False             False            False          False
#
#    addr_state_AR  addr_state_AZ  addr_state_CA  addr_state_CO  addr_state_CT  \
# 0          False           True          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_DC  addr_state_DE  addr_state_FL  addr_state_GA  addr_state_HI  \
# 0          False          False          False          False          False
# 1          False          False          False           True          False
#
#    addr_state_IA  addr_state_IL  addr_state_KS  addr_state_KY  addr_state_LA  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_MA  addr_state_MD  addr_state_MI  addr_state_MN  addr_state_MO  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_MS  addr_state_MT  addr_state_NC  addr_state_NH  addr_state_NJ  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_NM  addr_state_NV  addr_state_NY  addr_state_OH  addr_state_OK  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_OR  addr_state_PA  addr_state_RI  addr_state_SC  addr_state_SD  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_TN  addr_state_TX  addr_state_UT  addr_state_VA  addr_state_VT  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_WA  addr_state_WI  addr_state_WV  addr_state_WY  \
# 0          False          False          False          False
# 1          False          False          False          False
#
#    debt_settlement_flag_Y
# 0                   False
# 1                   False

# %%
# Label encoding on 'grade' column
le = LabelEncoder()
le.fit(df2.grade)
print(le.classes_)
# Out:
# ['A' 'B' 'C' 'D' 'E' 'F' 'G']

# %%
# Update 'grade' column
df2.grade = le.transform(df2.grade)

# %%
# Label encoding on 'sub_grade' column
le2 = LabelEncoder()
le2.fit(df2.sub_grade)
le2.classes_
# Out:
# array(['A1', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5', 'C1',
#        'C2', 'C3', 'C4', 'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2',
#        'E3', 'E4', 'E5', 'F1', 'F2', 'F3', 'F4', 'F5', 'G1', 'G2', 'G3',
#        'G4', 'G5'], dtype=object)

# %%
# Update 'sub_grade' column
df2.sub_grade = le2.transform(df2.sub_grade)

# %%
df2.head(2)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 0       5000         5000           4975.0  36.0      10.0       162.87
# 1       2500         2500           2500.0  60.0      15.0        59.83
#
#    grade  sub_grade  emp_length  annual_inc  loan_status    dti  delinq_2yrs  \
# 0      1          6        10.0     24000.0   Fully Paid  27.65            0
# 1      2         13         0.0     30000.0  Charged Off   1.00            0
#
#    earliest_cr_line  inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  \
# 0                34               1         3        0      13648        83.7
# 1                20               5         3        0       1687         9.4
#
#    total_acc  total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# 0          9  5863.155187          5833.84          5000.00         863.16
# 1          4  1014.530000          1014.53           456.46         435.17
#
#    total_rec_late_fee  recoveries  collection_recovery_fee  last_pymnt_amnt  \
# 0                 0.0         0.0                     0.00           171.62
# 1                 0.0       122.9                     1.11           119.66
#
#    pub_rec_bankruptcies  issue_d_year  issue_d_month  last_pymnt_d_year  \
# 0                   0.0             8             12                4.0
# 1                   0.0             8             12                6.0
#
#    last_pymnt_d_month  last_credit_pull_d_year  last_credit_pull_d_month  \
# 0                 1.0                      1.0                       7.0
# 1                 4.0                      3.0                      10.0
#
#    home_ownership_OTHER  home_ownership_OWN  home_ownership_RENT  \
# 0                 False               False                 True
# 1                 False               False                 True
#
#    verification_status_Source Verified  verification_status_Verified  \
# 0                                False                          True
# 1                                 True                         False
#
#    purpose_credit_card  purpose_debt_consolidation  purpose_educational  \
# 0                 True                       False                False
# 1                False                       False                False
#
#    purpose_home_improvement  purpose_house  purpose_major_purchase  \
# 0                     False          False                   False
# 1                     False          False                   False
#
#    purpose_medical  purpose_moving  purpose_other  purpose_renewable_energy  \
# 0            False           False          False                     False
# 1            False           False          False                     False
#
#    purpose_small_business  purpose_vacation  purpose_wedding  addr_state_AL  \
# 0                   False             False            False          False
# 1                   False             False            False          False
#
#    addr_state_AR  addr_state_AZ  addr_state_CA  addr_state_CO  addr_state_CT  \
# 0          False           True          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_DC  addr_state_DE  addr_state_FL  addr_state_GA  addr_state_HI  \
# 0          False          False          False          False          False
# 1          False          False          False           True          False
#
#    addr_state_IA  addr_state_IL  addr_state_KS  addr_state_KY  addr_state_LA  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_MA  addr_state_MD  addr_state_MI  addr_state_MN  addr_state_MO  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_MS  addr_state_MT  addr_state_NC  addr_state_NH  addr_state_NJ  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_NM  addr_state_NV  addr_state_NY  addr_state_OH  addr_state_OK  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_OR  addr_state_PA  addr_state_RI  addr_state_SC  addr_state_SD  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_TN  addr_state_TX  addr_state_UT  addr_state_VA  addr_state_VT  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_WA  addr_state_WI  addr_state_WV  addr_state_WY  \
# 0          False          False          False          False
# 1          False          False          False          False
#
#    debt_settlement_flag_Y
# 0                   False
# 1                   False

# %%
# Target feature
df2['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off'], dtype=object)

# %%
# Prediction features
X = df2.drop("loan_status", axis = 1)
# Target variable
y = df2['loan_status']
y.value_counts()
# Out:
# loan_status
# Fully Paid     26308
# Charged Off     4526
# Name: count, dtype: int64

# %%
# Label encoding the target variable
le3 = LabelEncoder()
le3.fit(y)
y_transformed = le3.transform(y)
y_transformed
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
X.head(2)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 0       5000         5000           4975.0  36.0      10.0       162.87
# 1       2500         2500           2500.0  60.0      15.0        59.83
#
#    grade  sub_grade  emp_length  annual_inc    dti  delinq_2yrs  \
# 0      1          6        10.0     24000.0  27.65            0
# 1      2         13         0.0     30000.0   1.00            0
#
#    earliest_cr_line  inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  \
# 0                34               1         3        0      13648        83.7
# 1                20               5         3        0       1687         9.4
#
#    total_acc  total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# 0          9  5863.155187          5833.84          5000.00         863.16
# 1          4  1014.530000          1014.53           456.46         435.17
#
#    total_rec_late_fee  recoveries  collection_recovery_fee  last_pymnt_amnt  \
# 0                 0.0         0.0                     0.00           171.62
# 1                 0.0       122.9                     1.11           119.66
#
#    pub_rec_bankruptcies  issue_d_year  issue_d_month  last_pymnt_d_year  \
# 0                   0.0             8             12                4.0
# 1                   0.0             8             12                6.0
#
#    last_pymnt_d_month  last_credit_pull_d_year  last_credit_pull_d_month  \
# 0                 1.0                      1.0                       7.0
# 1                 4.0                      3.0                      10.0
#
#    home_ownership_OTHER  home_ownership_OWN  home_ownership_RENT  \
# 0                 False               False                 True
# 1                 False               False                 True
#
#    verification_status_Source Verified  verification_status_Verified  \
# 0                                False                          True
# 1                                 True                         False
#
#    purpose_credit_card  purpose_debt_consolidation  purpose_educational  \
# 0                 True                       False                False
# 1                False                       False                False
#
#    purpose_home_improvement  purpose_house  purpose_major_purchase  \
# 0                     False          False                   False
# 1                     False          False                   False
#
#    purpose_medical  purpose_moving  purpose_other  purpose_renewable_energy  \
# 0            False           False          False                     False
# 1            False           False          False                     False
#
#    purpose_small_business  purpose_vacation  purpose_wedding  addr_state_AL  \
# 0                   False             False            False          False
# 1                   False             False            False          False
#
#    addr_state_AR  addr_state_AZ  addr_state_CA  addr_state_CO  addr_state_CT  \
# 0          False           True          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_DC  addr_state_DE  addr_state_FL  addr_state_GA  addr_state_HI  \
# 0          False          False          False          False          False
# 1          False          False          False           True          False
#
#    addr_state_IA  addr_state_IL  addr_state_KS  addr_state_KY  addr_state_LA  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_MA  addr_state_MD  addr_state_MI  addr_state_MN  addr_state_MO  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_MS  addr_state_MT  addr_state_NC  addr_state_NH  addr_state_NJ  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_NM  addr_state_NV  addr_state_NY  addr_state_OH  addr_state_OK  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_OR  addr_state_PA  addr_state_RI  addr_state_SC  addr_state_SD  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_TN  addr_state_TX  addr_state_UT  addr_state_VA  addr_state_VT  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
#
#    addr_state_WA  addr_state_WI  addr_state_WV  addr_state_WY  \
# 0          False          False          False          False
# 1          False          False          False          False
#
#    debt_settlement_flag_Y
# 0                   False
# 1                   False

# %% [markdown]
# ### Split data into training and testing set

# %%
# Split the data into train and test
x_train, x_test, y_train, y_test = train_test_split(X, y_transformed, test_size = 0.20, stratify = y_transformed, random_state = 2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((24667, 98), (24667,), (6167, 98), (6167,))

# %% [markdown]
# ## Model Building

# %%
# Using DecisionTree as base model
giniDecisionTree = DecisionTreeClassifier(criterion='gini', random_state = 100,
                                          max_depth=3, class_weight = 'balanced', min_samples_leaf = 5)
giniDecisionTree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=3, min_samples_leaf=5,
#                        random_state=100)

# %%
# Prediciton using DecisionTree
giniPred = giniDecisionTree.predict(x_test)
print('Accuracy Score: ', accuracy_score(y_test, giniPred))
# Out:
# Accuracy Score:  0.999513539808659

# %% [markdown]
# ### CatBoost

# %%
# Create CatBoostClassifier object
CatBoost_clf = CatBoostClassifier(iterations=5,
                                  learning_rate=0.1,
                                  #loss_function='CrossEntropy'
                                  )

# %%
#cat_features = list(range(0, X.shape[1]))
CatBoost_clf.fit(x_train, y_train,
                 #cat_features=cat_features,
                 eval_set = (x_test, y_test),
                 verbose = False)

# %%
# Prediction using CatBoost
cbr_prediction = CatBoost_clf.predict(x_test)
print('Accuracy Score: ', accuracy_score(y_test, cbr_prediction))
# Out:
# Accuracy Score:  0.9985406194259769

# %%
#  Classification report for CatBoost model
print('Classification Report for CatBoost:')
print(classification_report(y_test, cbr_prediction))
# Out:
# Classification Report for CatBoost:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       905
#            1       1.00      1.00      1.00      5262
#
#     accuracy                           1.00      6167
#    macro avg       1.00      1.00      1.00      6167
# weighted avg       1.00      1.00      1.00      6167

# %% [markdown]
# ### XGBoost

# %%
# Create XGBClassifier object

from xgboost import XGBClassifier

XGB_clf = XGBClassifier(learning_rate = 0.1)

# %%
from xgboost import XGBClassifier

# Initialize the model with eval_metric set in the constructor
model = XGBClassifier(eval_metric="logloss", early_stopping_rounds=10)

# Fit on training set
model.fit(x_train, y_train,
          eval_set=[(x_train, y_train), (x_test, y_test)],
          verbose=False)  # Suppress verbose output to avoid display issues

# Optionally, print the model to avoid the display error
print(model)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# Initialize and fit the model
XGB_clf = XGBClassifier(eval_metric="logloss")
XGB_clf.fit(x_train, y_train, eval_set=[(x_train, y_train), (x_test, y_test)], verbose=False)

# Prediction using XGBClassifier
XGB_prediction = XGB_clf.predict(x_test)

# Print the accuracy score
print('Accuracy Score: ', accuracy_score(y_test, XGB_prediction))
# Out:
# Accuracy Score:  0.9991892330144316

# %%
# Classification report for XGBoost

print('Classification Report for XGBoost:')
print(classification_report(y_test, XGB_prediction))
# Out:
# Classification Report for XGBoost:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       905
#            1       1.00      1.00      1.00      5262
#
#     accuracy                           1.00      6167
#    macro avg       1.00      1.00      1.00      6167
# weighted avg       1.00      1.00      1.00      6167

# %% [markdown]
# ### LightGBM

# %%
# Create LGBMClassifier object
import lightgbm as lgb
from lightgbm import LGBMClassifier

LGBM_clf = LGBMClassifier(learning_rate = 0.1)

# %%
from lightgbm import LGBMClassifier, early_stopping, log_evaluation

# Initialize the model
LGBM_clf = LGBMClassifier()

# Fit the model using early stopping
LGBM_clf.fit(
    x_train, y_train,
    eval_set=[(x_train, y_train), (x_test, y_test)],
    eval_metric="logloss",  # Log-loss as the evaluation metric
    callbacks=[
        early_stopping(stopping_rounds=10),  # Stop after 10 rounds with no improvement
        log_evaluation(period=1)  # Log evaluation metrics every 1 iteration
    ]
)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 21046, number of negative: 3621
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005397 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4498
# [LightGBM] [Info] Number of data points in the train set: 24667, number of used features: 94
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.853205 -> initscore=1.759960
# [LightGBM] [Info] Start training from score 1.759960
# [1]	training's binary_logloss: 0.323697	valid_1's binary_logloss: 0.323213
# Training until validation scores don't improve for 10 rounds
# [2]	training's binary_logloss: 0.270866	valid_1's binary_logloss: 0.27025
# [3]	training's binary_logloss: 0.232468	valid_1's binary_logloss: 0.231823
# [4]	training's binary_logloss: 0.202177	valid_1's binary_logloss: 0.201644
# [5]	training's binary_logloss: 0.177381	valid_1's binary_logloss: 0.17694
# [6]	training's binary_logloss: 0.156557	valid_1's binary_logloss: 0.156204
# [7]	training's binary_logloss: 0.138829	valid_1's binary_logloss: 0.13854
# [8]	training's binary_logloss: 0.12337	valid_1's binary_logloss: 0.12334
# [9]	training's binary_logloss: 0.109991	valid_1's binary_logloss: 0.11012
# [10]	training's binary_logloss: 0.0982448	valid_1's binary_logloss: 0.0985404
# [11]	training's binary_logloss: 0.0879313	valid_1's binary_logloss: 0.0883596
# [12]	training's binary_logloss: 0.0788289	valid_1's binary_logloss: 0.0793612
# [13]	training's binary_logloss: 0.0707709	valid_1's binary_logloss: 0.0714073
# [14]	training's binary_logloss: 0.0636063	valid_1's binary_logloss: 0.0643312
# [15]	training's binary_logloss: 0.0572443	valid_1's binary_logloss: 0.0580389
# [16]	training's binary_logloss: 0.0515517	valid_1's binary_logloss: 0.0524237
# [17]	training's binary_logloss: 0.0464566	valid_1's binary_logloss: 0.0474209
# [18]	training's binary_logloss: 0.0419014	valid_1's binary_logloss: 0.0429493
# [19]	training's binary_logloss: 0.0378057	valid_1's binary_logloss: 0.0389405
# [20]	training's binary_logloss: 0.0341327	valid_1's binary_logloss: 0.0353512
# [21]	training's binary_logloss: 0.0308353	valid_1's binary_logloss: 0.0321323
# [22]	training's binary_logloss: 0.02786	valid_1's binary_logloss: 0.0292511
# [23]	training's binary_logloss: 0.0251854	valid_1's binary_logloss: 0.0266677
# [24]	training's binary_logloss: 0.0227822	valid_1's binary_logloss: 0.024345
# [25]	training's binary_logloss: 0.0206103	valid_1's binary_logloss: 0.0222542
# [26]	training's binary_logloss: 0.0186449	valid_1's binary_logloss: 0.0203791
# [27]	training's binary_logloss: 0.0168599	valid_1's binary_logloss: 0.0186203
# [28]	training's binary_logloss: 0.0152453	valid_1's binary_logloss: 0.0170636
# [29]	training's binary_logloss: 0.0137886	valid_1's binary_logloss: 0.0156466
# [30]	training's binary_logloss: 0.0124738	valid_1's binary_logloss: 0.0143749
# [31]	training's binary_logloss: 0.0112861	valid_1's binary_logloss: 0.0132322
# [32]	training's binary_logloss: 0.0102083	valid_1's binary_logloss: 0.0122338
# [33]	training's binary_logloss: 0.00923986	valid_1's binary_logloss: 0.0112866
# [34]	training's binary_logloss: 0.0083645	valid_1's binary_logloss: 0.0104385
# [35]	training's binary_logloss: 0.00757393	valid_1's binary_logloss: 0.00967936
# [36]	training's binary_logloss: 0.00685767	valid_1's binary_logloss: 0.00903061
# [37]	training's binary_logloss: 0.00620771	valid_1's binary_logloss: 0.00840233
# [38]	training's binary_logloss: 0.00562338	valid_1's binary_logloss: 0.00786338
# [39]	training's binary_logloss: 0.00509009	valid_1's binary_logloss: 0.00735973
# [40]	training's binary_logloss: 0.00460695	valid_1's binary_logloss: 0.00690042
# [41]	training's binary_logloss: 0.00417311	valid_1's binary_logloss: 0.00649642
# [42]	training's binary_logloss: 0.00378073	valid_1's binary_logloss: 0.00614701
# [43]	training's binary_logloss: 0.0034245	valid_1's binary_logloss: 0.00581218
# [44]	training's binary_logloss: 0.00310132	valid_1's binary_logloss: 0.00553968
# [45]	training's binary_logloss: 0.00281025	valid_1's binary_logloss: 0.00528489
# [46]	training's binary_logloss: 0.00254683	valid_1's binary_logloss: 0.00505377
# [47]	training's binary_logloss: 0.00230567	valid_1's binary_logloss: 0.00486416
# [48]	training's binary_logloss: 0.00209019	valid_1's binary_logloss: 0.00466983
# [49]	training's binary_logloss: 0.00189403	valid_1's binary_logloss: 0.00450607
# [50]	training's binary_logloss: 0.00171874	valid_1's binary_logloss: 0.00436328
# [51]	training's binary_logloss: 0.00155726	valid_1's binary_logloss: 0.0042249
# [52]	training's binary_logloss: 0.00141273	valid_1's binary_logloss: 0.004102
# [53]	training's binary_logloss: 0.00128175	valid_1's binary_logloss: 0.00401929
# [54]	training's binary_logloss: 0.00116245	valid_1's binary_logloss: 0.00394993
# [55]	training's binary_logloss: 0.00105335	valid_1's binary_logloss: 0.00386549
# [56]	training's binary_logloss: 0.000955719	valid_1's binary_logloss: 0.00378871
# [57]	training's binary_logloss: 0.000867301	valid_1's binary_logloss: 0.00372756
# [58]	training's binary_logloss: 0.000787664	valid_1's binary_logloss: 0.00369616
# [59]	training's binary_logloss: 0.000714206	valid_1's binary_logloss: 0.00364825
# [60]	training's binary_logloss: 0.000648135	valid_1's binary_logloss: 0.00360789
# [61]	training's binary_logloss: 0.000587655	valid_1's binary_logloss: 0.00356857
# [62]	training's binary_logloss: 0.00053395	valid_1's binary_logloss: 0.00353607
# [63]	training's binary_logloss: 0.000484467	valid_1's binary_logloss: 0.00350822
# [64]	training's binary_logloss: 0.000440544	valid_1's binary_logloss: 0.0034996
# [65]	training's binary_logloss: 0.000399619	valid_1's binary_logloss: 0.00347976
# [66]	training's binary_logloss: 0.000362472	valid_1's binary_logloss: 0.00345961
# [67]	training's binary_logloss: 0.0003292	valid_1's binary_logloss: 0.00347318
# [68]	training's binary_logloss: 0.000299133	valid_1's binary_logloss: 0.00346321
# [69]	training's binary_logloss: 0.0002712	valid_1's binary_logloss: 0.00345738
# [70]	training's binary_logloss: 0.000246172	valid_1's binary_logloss: 0.00345695
# [71]	training's binary_logloss: 0.000223103	valid_1's binary_logloss: 0.00347132
# [72]	training's binary_logloss: 0.000202258	valid_1's binary_logloss: 0.00348121
# [73]	training's binary_logloss: 0.00018363	valid_1's binary_logloss: 0.0035032
# [74]	training's binary_logloss: 0.000166373	valid_1's binary_logloss: 0.00353162
# [75]	training's binary_logloss: 0.000150907	valid_1's binary_logloss: 0.00353277
# [76]	training's binary_logloss: 0.00013679	valid_1's binary_logloss: 0.00354176
# [77]	training's binary_logloss: 0.000124011	valid_1's binary_logloss: 0.00357579
# [78]	training's binary_logloss: 0.000112269	valid_1's binary_logloss: 0.00361007
# [79]	training's binary_logloss: 0.000101955	valid_1's binary_logloss: 0.0036249
# [80]	training's binary_logloss: 9.23081e-05	valid_1's binary_logloss: 0.00366148
# Early stopping, best iteration is:
# [70]	training's binary_logloss: 0.000246172	valid_1's binary_logloss: 0.00345695
# LGBMClassifier()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Prediction using LGBMClassifier
LGBM_prediction = LGBM_clf.predict(x_test)
print('Accuracy Score: ', accuracy_score(y_test, LGBM_prediction))
# Out:
# Accuracy Score:  0.999513539808659

# %%
# Classification report for LGBM

print('Classification Report for LGBM:')
print(classification_report(y_test, LGBM_prediction))
# Out:
# Classification Report for LGBM:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       905
#            1       1.00      1.00      1.00      5262
#
#     accuracy                           1.00      6167
#    macro avg       1.00      1.00      1.00      6167
# weighted avg       1.00      1.00      1.00      6167
